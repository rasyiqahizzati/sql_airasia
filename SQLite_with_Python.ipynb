# %% [markdown]
# <a href="https://colab.research.google.com/github/rasyiqahizzati/sql_airasia/blob/main/SQLite_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to SQL with SQLite in Python

# %% [markdown]
# Refer to [THIS WEBSITE](https://www.sqlite.org/index.html) about SQLite.

# %% [markdown]
# ## **Initialization**

# %% [markdown]
# ### Import necessary library

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ### Connect to a database
# If a database does not exist, it will be created.
# You may connect to a memory (temporary) database as well!

# %%
# dbconnection = sqlite3.connect('mydb.sqlite')
dbconnection = sqlite3.connect(':memory')

# %% [markdown]
# ### Create a cursor
# A cursor "translates" our codes to "tell" what a database should do.

# %%
# let's name our cursor "c" for typing convenience
c = dbconnection.cursor()

# %% [markdown]
# ### List all tables in a database

# %%
query = """

SELECT name FROM sqlite_master WHERE type = 'table';

"""

result = c.execute(query).fetchall();
print(result)
# Out:
# [('hr',)]

# %% [markdown]
# ### Commit (save) the changes
# Use this if you were to execute your codes from a .py file

# %%
dbconnection.commit()

# %% [markdown]
# ### Close the connection

# %%
dbconnection.close()

# %% [markdown]
# ## **Create a table**
# We can create many tables in a database. In most use cases, they are relational.
# Note: There are 5 datatypes in sqlite:
# * NULL
# * INTEGER
# * REAL (float / decimal number)
# * TEXT
# * BLOB (binary large object - normally image, documents, etc)

# %%
query = """

CREATE TABLE PetterRabbit (
  users TEXT,
  n_visit INTEGER,
  duration REAL
)

"""

c.execute(query);

# %% [markdown]
# ### Insert data into the table

# %%
# insert one record

query = """

INSERT INTO PetterRabbit
VALUES ('Bugs Bunny', 60, 6.5)

"""

c.execute(query);

# %%
# use a list with tuples to insert multiple records

data = [
        ('Peter Rabbit', 50, 5),
        ('Flopsy Rabbit', 40, 4),
        ('Mopsy Rabbit', 30, 3),
        ('Cottontail Rabbit', 20, 2),
        ('Benjamin Bunny', 10, 1)
]

query = """

INSERT INTO PetterRabbit
VALUES (?, ?, ?)

"""

c.executemany(query, data);

# %% [markdown]
# ## **Query a database**

# %%
query = """

SELECT * FROM PetterRabbit

"""

c.execute(query).fetchall();

# %% [markdown]
# Print the query result.

# %%
query = """

SELECT * FROM PetterRabbit

"""

print(c.execute(query).fetchall())
# Out:
# [('Bugs Bunny', 60, 6.5), ('Peter Rabbit', 50, 5.0), ('Flopsy Rabbit', 40, 4.0), ('Mopsy Rabbit', 30, 3.0), ('Cottontail Rabbit', 20, 2.0), ('Benjamin Bunny', 10, 1.0)]

# %% [markdown]
# We may also use pandas to fetch the results as data frame.

# %%
query = """

SELECT * FROM PetterRabbit

"""

pd.read_sql_query(query, dbconnection)
# Out:
#                users  n_visit  duration
# 0         Bugs Bunny       60       6.5
# 1       Peter Rabbit       50       5.0
# 2      Flopsy Rabbit       40       4.0
# 3       Mopsy Rabbit       30       3.0
# 4  Cottontail Rabbit       20       2.0
# 5     Benjamin Bunny       10       1.0

# %% [markdown]
# ## **Create table (import) from csv**
# Reference: https://mungingdata.com/sqlite/create-database-load-csv-python/
#
# Before we continue, upload the [HR Data](https://drive.google.com/file/d/1rA31hltWfpQcVUHtl-eeja2vnPB0P_KH/view?usp=sharing) to the current workspace.

# %%
df = pd.read_csv("hr_data.csv").iloc[:,1:]
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a516410e3b8c> in <module>()
# ----> 1 df = pd.read_csv("hr_data.csv").iloc[:,1:]
#       2 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hr_data.csv'

# %%
dbconnection = sqlite3.connect('mydb.sqlite')
# c = dbconnection.cursor()
df.to_sql('hr', dbconnection, if_exists = 'append', index = False)

# %% [markdown]
# ## **SQL Query**

# %% [markdown]
# ### 1: SELECT
#
#
# Basic syntax of the SELECT statement.
#
# ```
# SELECT column1, column2, columnN
# FROM table_name;
# ```
#
# Here, `column1`, `column2` … are the fields (columns) of a table whose values you want to fetch. If you want to fetch all the fields, use the following syntax.
#
# ```
# SELECT *
# FROM table_name;
# ```

# %%
query = """

SELECT city
FROM hr

"""

pd.read_sql_query(query, dbconnection)
# Out:
#            city
# 0      city_103
# 1       city_40
# 2       city_21
# 3      city_115
# 4      city_162
# ...         ...
# 19153  city_173
# 19154  city_103
# 19155  city_103
# 19156   city_65
# 19157   city_67
#
# [19158 rows x 1 columns]

# %% [markdown]
# ### 2: Select Multiple Columns

# %%
query = """

SELECT city, gender
FROM hr

"""

pd.read_sql_query(query, dbconnection)
# Out:
#            city gender
# 0      city_103   Male
# 1       city_40   Male
# 2       city_21   None
# 3      city_115   None
# 4      city_162   Male
# ...         ...    ...
# 19153  city_173   Male
# 19154  city_103   Male
# 19155  city_103   Male
# 19156   city_65   Male
# 19157   city_67   None
#
# [19158 rows x 2 columns]

# %%
query = """

SELECT *
FROM hr

"""

pd.read_sql_query(query, dbconnection)
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624   None   No relevent experience
# 3      city_115                   0.789   None   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855   None   No relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0           no_enrollment        Graduate             STEM        >20
# 1           no_enrollment        Graduate             STEM         15
# 2        Full time course        Graduate             STEM          5
# 3                    None        Graduate  Business Degree         <1
# 4           no_enrollment         Masters             STEM        >20
# ...                   ...             ...              ...        ...
# 19153       no_enrollment        Graduate       Humanities         14
# 19154       no_enrollment        Graduate             STEM         14
# 19155       no_enrollment        Graduate             STEM        >20
# 19156       no_enrollment     High School             None         <1
# 19157       no_enrollment  Primary School             None          2
#
#       company_size    company_type last_new_job  training_hours  target
# 0             None            None            1              36     1.0
# 1            50-99         Pvt Ltd           >4              47     0.0
# 2             None            None        never              83     0.0
# 3             None         Pvt Ltd        never              52     1.0
# 4            50-99  Funded Startup            4               8     0.0
# ...            ...             ...          ...             ...     ...
# 19153         None            None            1              42     1.0
# 19154         None            None            4              52     1.0
# 19155        50-99         Pvt Ltd            4              44     0.0
# 19156      500-999         Pvt Ltd            2              97     0.0
# 19157         None            None            1             127     0.0
#
# [19158 rows x 13 columns]

# %% [markdown]
# ### 3： SELECT DISTINCT
#
# Return only the distinct (different) values.

# %%
query = """

SELECT DISTINCT relevent_experience
FROM hr

"""

pd.read_sql_query(query, dbconnection)
# Out:
#        relevent_experience
# 0  Has relevent experience
# 1   No relevent experience

# %% [markdown]
# ### 4: WHERE Clause - filter rows

# %%
query = """

SELECT city, city_development_index
FROM hr
WHERE city_development_index < 0.5

"""

pd.read_sql_query(query, dbconnection)
# Out:
#         city  city_development_index
# 0    city_48                   0.493
# 1   city_126                   0.479
# 2   city_126                   0.479
# 3   city_126                   0.479
# 4   city_126                   0.479
# ..       ...                     ...
# 58   city_48                   0.493
# 59   city_33                   0.448
# 60   city_33                   0.448
# 61  city_139                   0.487
# 62  city_126                   0.479
#
# [63 rows x 2 columns]

# %%
query = """

SELECT *
FROM hr
WHERE relevent_experience = 'Has relevent experience'

"""

pd.read_sql_query(query, dbconnection)
# Out:
#            city  city_development_index  gender      relevent_experience  \
# 0      city_103                   0.920    Male  Has relevent experience
# 1      city_162                   0.767    Male  Has relevent experience
# 2      city_176                   0.764    None  Has relevent experience
# 3      city_160                   0.920    Male  Has relevent experience
# 4       city_46                   0.762    Male  Has relevent experience
# ...         ...                     ...     ...                      ...
# 13787  city_160                   0.920  Female  Has relevent experience
# 13788  city_103                   0.920  Female  Has relevent experience
# 13789  city_103                   0.920    Male  Has relevent experience
# 13790  city_103                   0.920    Male  Has relevent experience
# 13791   city_65                   0.802    Male  Has relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0           no_enrollment        Graduate             STEM        >20
# 1           no_enrollment         Masters             STEM        >20
# 2        Part time course        Graduate             STEM         11
# 3           no_enrollment     High School             None          5
# 4           no_enrollment        Graduate             STEM         13
# ...                   ...             ...              ...        ...
# 13787       no_enrollment        Graduate             STEM         10
# 13788       no_enrollment        Graduate       Humanities          7
# 13789       no_enrollment        Graduate             STEM         14
# 13790       no_enrollment        Graduate             STEM        >20
# 13791       no_enrollment     High School             None         <1
#
#       company_size    company_type last_new_job  training_hours  target
# 0             None            None            1              36     1.0
# 1            50-99  Funded Startup            4               8     0.0
# 2             None            None            1              24     1.0
# 3            50-99  Funded Startup            1              24     0.0
# 4              <10         Pvt Ltd           >4              18     1.0
# ...            ...             ...          ...             ...     ...
# 13787      100-500   Public Sector            3              23     0.0
# 13788        10/49  Funded Startup            1              25     0.0
# 13789         None            None            4              52     1.0
# 13790        50-99         Pvt Ltd            4              44     0.0
# 13791      500-999         Pvt Ltd            2              97     0.0
#
# [13792 rows x 13 columns]

# %% [markdown]
# Take note that for SQL, we just use one equal `=` sign.

# %% [markdown]
# ### 5: Operators in The WHERE Clause
#
# | Operator | Description |
# | --- | --- |
# | = |	Equal	|
# | >	| Greater than |
# | <	| Less than |
# | >= |	Greater than or equal |
# | <= |	Less than or equal |
# | <>	| Not equal. Note: In some versions of SQL this operator may be written as != |
# | BETWEEN |	Between a certain range |
# |LIKE |	Search for a pattern	|
# | IN |	To specify multiple possible values for a column |

# %%
query = """

SELECT *
FROM hr
WHERE education_level LIKE '%ra%'

"""

pd.read_sql_query(query, dbconnection)
# Out:
#            city  city_development_index  gender      relevent_experience  \
# 0      city_103                   0.920    Male  Has relevent experience
# 1       city_40                   0.776    Male   No relevent experience
# 2       city_21                   0.624    None   No relevent experience
# 3      city_115                   0.789    None   No relevent experience
# 4      city_176                   0.764    None  Has relevent experience
# ...         ...                     ...     ...                      ...
# 11593  city_149                   0.689    Male   No relevent experience
# 11594  city_103                   0.920  Female  Has relevent experience
# 11595  city_173                   0.878    Male   No relevent experience
# 11596  city_103                   0.920    Male  Has relevent experience
# 11597  city_103                   0.920    Male  Has relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0           no_enrollment        Graduate             STEM        >20
# 1           no_enrollment        Graduate             STEM         15
# 2        Full time course        Graduate             STEM          5
# 3                    None        Graduate  Business Degree         <1
# 4        Part time course        Graduate             STEM         11
# ...                   ...             ...              ...        ...
# 11593    Full time course        Graduate             None          2
# 11594       no_enrollment        Graduate       Humanities          7
# 11595       no_enrollment        Graduate       Humanities         14
# 11596       no_enrollment        Graduate             STEM         14
# 11597       no_enrollment        Graduate             STEM        >20
#
#       company_size    company_type last_new_job  training_hours  target
# 0             None            None            1              36     1.0
# 1            50-99         Pvt Ltd           >4              47     0.0
# 2             None            None        never              83     0.0
# 3             None         Pvt Ltd        never              52     1.0
# 4             None            None            1              24     1.0
# ...            ...             ...          ...             ...     ...
# 11593         None            None            1              60     0.0
# 11594        10/49  Funded Startup            1              25     0.0
# 11595         None            None            1              42     1.0
# 11596         None            None            4              52     1.0
# 11597        50-99         Pvt Ltd            4              44     0.0
#
# [11598 rows x 13 columns]

# %%
query = """

SELECT *
FROM hr
WHERE city_development_index BETWEEN 0.8 AND 0.9

"""

pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index  gender      relevent_experience  \
# 0      city_13                   0.827  Female  Has relevent experience
# 1     city_159                   0.843    Male  Has relevent experience
# 2     city_102                   0.804    None  Has relevent experience
# 3      city_67                   0.855    None   No relevent experience
# 4     city_100                   0.887    Male  Has relevent experience
# ...        ...                     ...     ...                      ...
# 3544   city_65                   0.802    Male  Has relevent experience
# 3545   city_23                   0.899    Male  Has relevent experience
# 3546  city_173                   0.878    Male   No relevent experience
# 3547   city_65                   0.802    Male  Has relevent experience
# 3548   city_67                   0.855    None   No relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 0          no_enrollment        Graduate             Arts          4
# 1          no_enrollment         Masters             STEM         11
# 2          no_enrollment         Masters             STEM         10
# 3          no_enrollment     High School             None          4
# 4          no_enrollment     High School             None         11
# ...                  ...             ...              ...        ...
# 3544       no_enrollment        Graduate             STEM          8
# 3545       no_enrollment        Graduate             STEM         17
# 3546       no_enrollment        Graduate       Humanities         14
# 3547       no_enrollment     High School             None         <1
# 3548       no_enrollment  Primary School             None          2
#
#      company_size    company_type last_new_job  training_hours  target
# 0            None            None            1             132     1.0
# 1         100-500         Pvt Ltd            1              68     0.0
# 2            None            None            1              48     0.0
# 3            None            None        never              22     0.0
# 4             <10         Pvt Ltd            1               8     1.0
# ...           ...             ...          ...             ...     ...
# 3544        50-99   Public Sector            2             136     0.0
# 3545        10/49  Funded Startup            3              12     0.0
# 3546         None            None            1              42     1.0
# 3547      500-999         Pvt Ltd            2              97     0.0
# 3548         None            None            1             127     0.0
#
# [3549 rows x 13 columns]

# %%
query = """

SELECT *
FROM hr
WHERE city IN ('city_23', 'city_173')

"""

pd.read_sql_query(query, dbconnection)
# Out:
#          city  city_development_index  gender      relevent_experience  \
# 0    city_173                   0.878    None   No relevent experience
# 1    city_173                   0.878    Male  Has relevent experience
# 2    city_173                   0.878  Female  Has relevent experience
# 3    city_173                   0.878    None   No relevent experience
# 4    city_173                   0.878    Male   No relevent experience
# ..        ...                     ...     ...                      ...
# 328   city_23                   0.899    Male  Has relevent experience
# 329  city_173                   0.878    Male   No relevent experience
# 330  city_173                   0.878    Male  Has relevent experience
# 331   city_23                   0.899    Male  Has relevent experience
# 332  city_173                   0.878    Male   No relevent experience
#
#     enrolled_university education_level major_discipline experience  \
# 0         no_enrollment         Masters             STEM        >20
# 1         no_enrollment        Graduate             STEM         12
# 2      Part time course     High School             None          2
# 3         no_enrollment        Graduate             STEM          5
# 4      Part time course        Graduate             STEM         10
# ..                  ...             ...              ...        ...
# 328       no_enrollment         Masters             STEM         15
# 329       no_enrollment  Primary School             None          6
# 330       no_enrollment     High School             None          6
# 331       no_enrollment        Graduate             STEM         17
# 332       no_enrollment        Graduate       Humanities         14
#
#     company_size         company_type last_new_job  training_hours  target
# 0           None                 None            1             150     0.0
# 1        100-500              Pvt Ltd            2               8     0.0
# 2        100-500                  NGO            1              22     0.0
# 3           None                 None            1              28     0.0
# 4          10/49  Early Stage Startup            1              25     0.0
# ..           ...                  ...          ...             ...     ...
# 328        50-99              Pvt Ltd            3              18     0.0
# 329         None                 None        never             106     0.0
# 330       10000+              Pvt Ltd            1             144     0.0
# 331        10/49       Funded Startup            3              12     0.0
# 332         None                 None            1              42     1.0
#
# [333 rows x 13 columns]

# %% [markdown]
# ### 6: `AND`, `OR` and `NOT` Operators

# %%
query = """

SELECT *
FROM hr
WHERE (city = 'city_103') AND (enrolled_university = 'no_enrollment')

"""

pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index  gender      relevent_experience  \
# 0     city_103                    0.92    Male  Has relevent experience
# 1     city_103                    0.92    Male  Has relevent experience
# 2     city_103                    0.92    None  Has relevent experience
# 3     city_103                    0.92    Male  Has relevent experience
# 4     city_103                    0.92    None  Has relevent experience
# ...        ...                     ...     ...                      ...
# 3610  city_103                    0.92    Male  Has relevent experience
# 3611  city_103                    0.92    Male  Has relevent experience
# 3612  city_103                    0.92  Female  Has relevent experience
# 3613  city_103                    0.92    Male  Has relevent experience
# 3614  city_103                    0.92    Male  Has relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 0          no_enrollment        Graduate             STEM        >20
# 1          no_enrollment        Graduate             STEM          7
# 2          no_enrollment        Graduate             STEM         17
# 3          no_enrollment        Graduate             STEM          5
# 4          no_enrollment        Graduate             STEM          1
# ...                  ...             ...              ...        ...
# 3610       no_enrollment        Graduate             STEM          5
# 3611       no_enrollment         Masters             STEM          9
# 3612       no_enrollment        Graduate       Humanities          7
# 3613       no_enrollment        Graduate             STEM         14
# 3614       no_enrollment        Graduate             STEM        >20
#
#      company_size    company_type last_new_job  training_hours  target
# 0            None            None            1              36     1.0
# 1           50-99         Pvt Ltd            1              46     1.0
# 2          10000+         Pvt Ltd           >4             123     0.0
# 3       5000-9999         Pvt Ltd            1             108     0.0
# 4           50-99         Pvt Ltd        never             106     0.0
# ...           ...             ...          ...             ...     ...
# 3610      500-999         Pvt Ltd            1              51     0.0
# 3611        50-99         Pvt Ltd            1              36     1.0
# 3612        10/49  Funded Startup            1              25     0.0
# 3613         None            None            4              52     1.0
# 3614        50-99         Pvt Ltd            4              44     0.0
#
# [3615 rows x 13 columns]

# %%
query = """

SELECT *
FROM hr
WHERE (city = 'city_103') OR (city = 'city_21')

"""

pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index  gender      relevent_experience  \
# 0     city_103                   0.920    Male  Has relevent experience
# 1      city_21                   0.624    None   No relevent experience
# 2     city_103                   0.920    Male  Has relevent experience
# 3     city_103                   0.920    None  Has relevent experience
# 4      city_21                   0.624    None   No relevent experience
# ...        ...                     ...     ...                      ...
# 7052   city_21                   0.624    None  Has relevent experience
# 7053  city_103                   0.920    Male  Has relevent experience
# 7054  city_103                   0.920  Female  Has relevent experience
# 7055  city_103                   0.920    Male  Has relevent experience
# 7056  city_103                   0.920    Male  Has relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 0          no_enrollment        Graduate             STEM        >20
# 1       Full time course        Graduate             STEM          5
# 2          no_enrollment        Graduate             STEM          7
# 3          no_enrollment        Graduate             STEM         17
# 4       Full time course     High School             None          2
# ...                  ...             ...              ...        ...
# 7052       no_enrollment         Masters             STEM          3
# 7053       no_enrollment         Masters             STEM          9
# 7054       no_enrollment        Graduate       Humanities          7
# 7055       no_enrollment        Graduate             STEM         14
# 7056       no_enrollment        Graduate             STEM        >20
#
#      company_size    company_type last_new_job  training_hours  target
# 0            None            None            1              36     1.0
# 1            None            None        never              83     0.0
# 2           50-99         Pvt Ltd            1              46     1.0
# 3          10000+         Pvt Ltd           >4             123     0.0
# 4            None            None        never              32     1.0
# ...           ...             ...          ...             ...     ...
# 7052      100-500         Pvt Ltd            3              40     1.0
# 7053        50-99         Pvt Ltd            1              36     1.0
# 7054        10/49  Funded Startup            1              25     0.0
# 7055         None            None            4              52     1.0
# 7056        50-99         Pvt Ltd            4              44     0.0
#
# [7057 rows x 13 columns]

# %%
query = """

SELECT *
FROM hr
WHERE NOT enrolled_university = 'no_enrollment'

"""

pd.read_sql_query(query, dbconnection)

#----------------------------------------------------#

# query = """

# SELECT *
# FROM hr
# WHERE enrolled_university <> 'no_enrollment'

# """

# pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index gender      relevent_experience  \
# 0      city_21                   0.624   None   No relevent experience
# 1     city_176                   0.764   None  Has relevent experience
# 2      city_21                   0.624   None   No relevent experience
# 3      city_21                   0.624   None   No relevent experience
# 4      city_21                   0.624   None  Has relevent experience
# ...        ...                     ...    ...                      ...
# 4950   city_21                   0.624   None  Has relevent experience
# 4951   city_21                   0.624   None   No relevent experience
# 4952   city_44                   0.725   None   No relevent experience
# 4953   city_21                   0.624   Male   No relevent experience
# 4954  city_149                   0.689   Male   No relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 0       Full time course        Graduate             STEM          5
# 1       Part time course        Graduate             STEM         11
# 2       Full time course     High School             None          2
# 3       Full time course     High School             None          5
# 4       Part time course        Graduate             STEM         14
# ...                  ...             ...              ...        ...
# 4950    Full time course        Graduate             STEM          4
# 4951    Full time course        Graduate             STEM          4
# 4952    Full time course        Graduate             STEM          5
# 4953    Full time course        Graduate             STEM          1
# 4954    Full time course        Graduate             None          2
#
#      company_size company_type last_new_job  training_hours  target
# 0            None         None        never              83     0.0
# 1            None         None            1              24     1.0
# 2            None         None        never              32     1.0
# 3            None         None        never              26     0.0
# 4         500-999      Pvt Ltd            1             148     1.0
# ...           ...          ...          ...             ...     ...
# 4950         None         None         None              13     0.0
# 4951         None         None        never              48     1.0
# 4952         None      Pvt Ltd        never             190     0.0
# 4953      100-500      Pvt Ltd            1              52     1.0
# 4954         None         None            1              60     0.0
#
# [4955 rows x 13 columns]

# %% [markdown]
# ### 7: `ORDER BY` Keyword
# Sort column(s) in result-set in ascending or descending order.

# %%
query = """

SELECT *
FROM hr
ORDER BY enrolled_university

"""

pd.read_sql_query(query, dbconnection)
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_115                   0.789   None   No relevent experience
# 1       city_21                   0.624   Male   No relevent experience
# 2       city_41                   0.827   None  Has relevent experience
# 3       city_90                   0.698   None   No relevent experience
# 4       city_70                   0.698   None  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855   None   No relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0                    None        Graduate  Business Degree         <1
# 1                    None            None             None          2
# 2                    None         Masters             STEM         13
# 3                    None            None             None          2
# 4                    None            None             None        >20
# ...                   ...             ...              ...        ...
# 19153       no_enrollment        Graduate       Humanities         14
# 19154       no_enrollment        Graduate             STEM         14
# 19155       no_enrollment        Graduate             STEM        >20
# 19156       no_enrollment     High School             None         <1
# 19157       no_enrollment  Primary School             None          2
#
#       company_size company_type last_new_job  training_hours  target
# 0             None      Pvt Ltd        never              52     1.0
# 1             None         None        never              24     0.0
# 2              <10         None            1              15     0.0
# 3             None      Pvt Ltd        never             228     1.0
# 4             None         None           >4              33     0.0
# ...            ...          ...          ...             ...     ...
# 19153         None         None            1              42     1.0
# 19154         None         None            4              52     1.0
# 19155        50-99      Pvt Ltd            4              44     0.0
# 19156      500-999      Pvt Ltd            2              97     0.0
# 19157         None         None            1             127     0.0
#
# [19158 rows x 13 columns]

# %%
query = """

SELECT *
FROM hr
ORDER BY city_development_index

"""

pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index gender      relevent_experience  \
# 0      city_33                   0.448   None  Has relevent experience
# 1      city_33                   0.448   None   No relevent experience
# 2      city_33                   0.448   Male   No relevent experience
# 3      city_33                   0.448   None   No relevent experience
# 4      city_33                   0.448   None  Has relevent experience
# ...        ...                     ...    ...                      ...
# 19153  city_98                   0.949   Male   No relevent experience
# 19154  city_98                   0.949   Male  Has relevent experience
# 19155  city_98                   0.949   Male  Has relevent experience
# 19156  city_98                   0.949   Male  Has relevent experience
# 19157  city_98                   0.949   Male  Has relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0        Part time course        Graduate             STEM         10
# 1        Full time course        Graduate             STEM          2
# 2           no_enrollment        Graduate             STEM          1
# 3                    None     High School             None          5
# 4        Part time course         Masters             STEM          6
# ...                   ...             ...              ...        ...
# 19153    Full time course        Graduate             STEM          1
# 19154       no_enrollment         Masters             STEM        >20
# 19155       no_enrollment        Graduate             STEM         14
# 19156       no_enrollment         Masters             STEM        >20
# 19157       no_enrollment        Graduate             STEM         11
#
#       company_size company_type last_new_job  training_hours  target
# 0            50-99          NGO           >4              48     1.0
# 1             None         None        never              43     1.0
# 2             None         None        never              73     1.0
# 3             None      Pvt Ltd        never              86     1.0
# 4             None         None            1              18     1.0
# ...            ...          ...          ...             ...     ...
# 19153    1000-4999      Pvt Ltd        never               3     1.0
# 19154        50-99      Pvt Ltd           >4              91     0.0
# 19155    5000-9999      Pvt Ltd            2             174     0.0
# 19156    1000-4999      Pvt Ltd           >4             105     0.0
# 19157       10000+      Pvt Ltd            1              45     0.0
#
# [19158 rows x 13 columns]

# %%
query = """

SELECT *
FROM hr
ORDER BY city ASC, education_level DESC, city_development_index DESC

"""

pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index  gender      relevent_experience  \
# 0       city_1                   0.847    Male  Has relevent experience
# 1       city_1                   0.847    Male  Has relevent experience
# 2       city_1                   0.847    Male  Has relevent experience
# 3       city_1                   0.847    Male  Has relevent experience
# 4       city_1                   0.847    Male  Has relevent experience
# ...        ...                     ...     ...                      ...
# 19153  city_99                   0.915  Female  Has relevent experience
# 19154  city_99                   0.915    Male  Has relevent experience
# 19155  city_99                   0.915    Male  Has relevent experience
# 19156  city_99                   0.915    Male  Has relevent experience
# 19157  city_99                   0.915    None  Has relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0        Full time course         Masters             STEM          6
# 1           no_enrollment         Masters             STEM         10
# 2        Full time course         Masters             STEM         11
# 3           no_enrollment         Masters             STEM          3
# 4        Full time course         Masters             STEM          6
# ...                   ...             ...              ...        ...
# 19153    Part time course        Graduate             STEM        >20
# 19154       no_enrollment        Graduate             STEM          9
# 19155       no_enrollment        Graduate             STEM        >20
# 19156       no_enrollment        Graduate             STEM          5
# 19157    Full time course        Graduate             STEM          5
#
#       company_size   company_type last_new_job  training_hours  target
# 0            10/49           None            1               3     0.0
# 1            50-99        Pvt Ltd            1              59     0.0
# 2             None           None           >4              13     0.0
# 3             None           None        never              39     0.0
# 4        5000-9999        Pvt Ltd            1              72     1.0
# ...            ...            ...          ...             ...     ...
# 19153      100-500  Public Sector            2             105     0.0
# 19154         None           None            1              25     0.0
# 19155         None           None           >4              94     1.0
# 19156      500-999        Pvt Ltd            1              28     0.0
# 19157        10/49           None            2              42     0.0
#
# [19158 rows x 13 columns]

# %% [markdown]
# ### 8: NULL Values
# Missing values

# %%
query = """

SELECT *
FROM hr
WHERE gender IS NULL

"""

pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index gender      relevent_experience  \
# 0      city_21                   0.624   None   No relevent experience
# 1     city_115                   0.789   None   No relevent experience
# 2     city_176                   0.764   None  Has relevent experience
# 3     city_103                   0.920   None  Has relevent experience
# 4      city_21                   0.624   None   No relevent experience
# ...        ...                     ...    ...                      ...
# 4503  city_103                   0.920   None   No relevent experience
# 4504   city_21                   0.624   None   No relevent experience
# 4505   city_44                   0.725   None   No relevent experience
# 4506   city_21                   0.624   None  Has relevent experience
# 4507   city_67                   0.855   None   No relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 0       Full time course        Graduate             STEM          5
# 1                   None        Graduate  Business Degree         <1
# 2       Part time course        Graduate             STEM         11
# 3          no_enrollment        Graduate             STEM         17
# 4       Full time course     High School             None          2
# ...                  ...             ...              ...        ...
# 4503       no_enrollment  Primary School             None          2
# 4504    Full time course        Graduate             STEM          4
# 4505    Full time course        Graduate             STEM          5
# 4506       no_enrollment         Masters             STEM          3
# 4507       no_enrollment  Primary School             None          2
#
#      company_size company_type last_new_job  training_hours  target
# 0            None         None        never              83     0.0
# 1            None      Pvt Ltd        never              52     1.0
# 2            None         None            1              24     1.0
# 3          10000+      Pvt Ltd           >4             123     0.0
# 4            None         None        never              32     1.0
# ...           ...          ...          ...             ...     ...
# 4503         None         None        never              15     0.0
# 4504         None         None        never              48     1.0
# 4505         None      Pvt Ltd        never             190     0.0
# 4506      100-500      Pvt Ltd            3              40     1.0
# 4507         None         None            1             127     0.0
#
# [4508 rows x 13 columns]

# %%
query = """

SELECT *
FROM hr
WHERE gender = ''

"""

pd.read_sql_query(query, dbconnection)
# Out:
# Empty DataFrame
# Columns: [city, city_development_index, gender, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target]
# Index: []

# %% [markdown]
# ### 9: UPDATE Values

# %%
query = """

UPDATE hr
SET gender = NULL
WHERE gender = ''

"""

c.execute(query);

# %%
query = """

SELECT *
FROM hr
WHERE gender IS NULL

"""

pd.read_sql_query(query, dbconnection)
# Out:
#           city  city_development_index gender      relevent_experience  \
# 0      city_21                   0.624   None   No relevent experience
# 1     city_115                   0.789   None   No relevent experience
# 2     city_176                   0.764   None  Has relevent experience
# 3     city_103                   0.920   None  Has relevent experience
# 4      city_21                   0.624   None   No relevent experience
# ...        ...                     ...    ...                      ...
# 4503  city_103                   0.920   None   No relevent experience
# 4504   city_21                   0.624   None   No relevent experience
# 4505   city_44                   0.725   None   No relevent experience
# 4506   city_21                   0.624   None  Has relevent experience
# 4507   city_67                   0.855   None   No relevent experience
#
#      enrolled_university education_level major_discipline experience  \
# 0       Full time course        Graduate             STEM          5
# 1                   None        Graduate  Business Degree         <1
# 2       Part time course        Graduate             STEM         11
# 3          no_enrollment        Graduate             STEM         17
# 4       Full time course     High School             None          2
# ...                  ...             ...              ...        ...
# 4503       no_enrollment  Primary School             None          2
# 4504    Full time course        Graduate             STEM          4
# 4505    Full time course        Graduate             STEM          5
# 4506       no_enrollment         Masters             STEM          3
# 4507       no_enrollment  Primary School             None          2
#
#      company_size company_type last_new_job  training_hours  target
# 0            None         None        never              83     0.0
# 1            None      Pvt Ltd        never              52     1.0
# 2            None         None            1              24     1.0
# 3          10000+      Pvt Ltd           >4             123     0.0
# 4            None         None        never              32     1.0
# ...           ...          ...          ...             ...     ...
# 4503         None         None        never              15     0.0
# 4504         None         None        never              48     1.0
# 4505         None      Pvt Ltd        never             190     0.0
# 4506      100-500      Pvt Ltd            3              40     1.0
# 4507         None         None            1             127     0.0
#
# [4508 rows x 13 columns]

# %% [markdown]
# ### 10: DELETE  records
# To delete existing records in a table

# %%
query = """

DELETE FROM hr
WHERE enrolled_university = ''

"""

c.execute(query);

# %% [markdown]
# ### 11: LIMIT
# Identical to df.head(n) in pandas.

# %%
query = """

SELECT *
FROM hr
LIMIT 3;

"""

pd.read_sql_query(query, dbconnection)
# Out:
#        city  city_development_index gender      relevent_experience  \
# 0  city_103                   0.920   Male  Has relevent experience
# 1   city_40                   0.776   Male   No relevent experience
# 2   city_21                   0.624   None   No relevent experience
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
# 2    Full time course        Graduate             STEM          5
#
#   company_size company_type last_new_job  training_hours  target
# 0         None         None            1              36     1.0
# 1        50-99      Pvt Ltd           >4              47     0.0
# 2         None         None        never              83     0.0

# %% [markdown]
# ### 12: Aggregation

# %%
query = """

SELECT relevent_experience, AVG(training_hours) average_training_hours
FROM hr
GROUP BY relevent_experience

"""

pd.read_sql_query(query, dbconnection)

# %% [markdown]
# ## Exercise
# Use HR data to answer the followings:

# %% [markdown]
# 1. How many records are there in the HR table?

# %% [markdown]
# 2. How many male employees in the HR table?

# %% [markdown]
# 3. What is the minumum and maximum training hours in the table?

# %% [markdown]
# 4. What is the education level of the employee who has maximum training hours and has enrolled in a part-time course?

# %% [markdown]
# 5. How many employees are staying in a city that has development index below 0.5?
